# %%
# %pip install tslearn
# %matplotlib inline
# Out:
# Requirement already satisfied: tslearn in d:\programfiles\anaconda\lib\site-packages (0.5.3.2)
# Requirement already satisfied: numpy in d:\programfiles\anaconda\lib\site-packages (from tslearn) (1.20.3)
# Requirement already satisfied: joblib in d:\programfiles\anaconda\lib\site-packages (from tslearn) (1.1.0)
# Requirement already satisfied: scikit-learn in d:\programfiles\anaconda\lib\site-packages (from tslearn) (0.24.2)
# Requirement already satisfied: scipy in d:\programfiles\anaconda\lib\site-packages (from tslearn) (1.7.1)
# Requirement already satisfied: numba in d:\programfiles\anaconda\lib\site-packages (from tslearn) (0.54.1)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in d:\programfiles\anaconda\lib\site-packages (from numba->tslearn) (0.37.0)
# Requirement already satisfied: setuptools in d:\programfiles\anaconda\lib\site-packages (from numba->tslearn) (58.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\programfiles\anaconda\lib\site-packages (from scikit-learn->tslearn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
from tslearn.metrics import dtw 
import matplotlib.pyplot as plt 
import matplotlib.cm as cm 
from tslearn.clustering import TimeSeriesKMeans

# %%
from numpy.random import randn
def sinx(a, dx, count, noise_factor):
    return a*np.sin(np.array([dx*i + randn()*noise_factor for i in range(count)]))

def cosx(a, dx, count, noise_factor):
    return a*np.cos(np.array([dx*i + randn()*noise_factor for i in range(count)]))

def line(a, x0, count, noise_factor):
    return np.array([a*i + randn()*noise_factor for i in range(count)])

def plot_datas(datas, colors=[]):
    count = len(datas[0])
    for i in range(len(datas)):
        if len(colors)!=0:
            plt.plot(np.arange(count), datas[i], c=colors[i])
        else:
            plt.plot(np.arange(count), datas[i])
    plt.show()
    
count = 100
noise_factor = 0.0
datas = [sinx(1, 0.1, count, noise_factor)
        , sinx(20, 0.5, count, noise_factor)
        , cosx(1, 0.1, count, noise_factor)
        , cosx(30, 0.5, count, noise_factor)
        , line(1, 1, count, noise_factor)]
df = pd.DataFrame(data = datas)
df2 = pd.DataFrame(data = datas[0:3])

datas = df.values
plot_datas(datas)
datas = df2.values
plot_datas(datas)

# %%
distortions = [] 

for i in range(1,11): 
    ts_km = TimeSeriesKMeans(n_clusters=i,metric="dtw",random_state=42) 
    ts_km.fit_predict(df)
    distortions.append(ts_km.inertia_) 

plt.plot(range(1,11),distortions,marker="o") 
plt.xticks(range(1,11)) 
plt.xlabel("Number of clusters") 
plt.ylabel("Distortion") 
plt.show()

ts_km = TimeSeriesKMeans(n_clusters=3,metric="dtw",random_state=42) 
y_pred = ts_km.fit_predict(df)
plot_datas(df.values, colors=[cm.tab20(y_pred[i]) for i in range(len(y_pred))])

# %%
import pickle as pkl
path = r"D:\atlas\u\lantaoyu\exps\airl\simple_tag\decentralized\s-1000\l-0.1-b-1000-d-0.1-c-500-l2-0.1-iter-1-r-0.0\seed-1\m_04000-100tra.pkl"
with open(path, "rb") as f:
    datas = pkl.load(f)

data = datas[0]
ob = data['ob']
ob = np.array([[str(x) for x in y] for y in ob])
ob = ob.T
df = pd.DataFrame(data = ob, index=["traj"+str(i) for i in range(ob.shape[0])], columns=['agent'+str(i) for i in range(ob.shape[1])])
df.head()
# Out:
#                                                   agent0  \
# traj0  [ 0.          0.         -0.54780504 -0.998468...
# traj1  [ 3.00000000e-001  0.00000000e+000 -4.87805039...
# traj2  [ 2.25000000e-001 -3.00000000e-001 -4.42805039...
# traj3  [ 4.68750000e-001 -2.25000000e-001 -3.49055039...
# traj4  [ 6.51562500e-001 -1.68750000e-001 -2.18742539...
#
#                                                   agent1  \
# traj0  [ 0.          0.          0.77719752 -0.635948...
# traj1  [ 3.00000000e-001 -9.75519470e-215  8.37197518...
# traj2  [ 5.25000000e-001 -6.78169971e-195  9.42197518...
# traj3  [ 9.37500000e-002 -1.48816425e-176  9.60947518...
# traj4  [-2.29687500e-001 -8.74321638e-141  9.15010018...
#
#                                                   agent2  \
# traj0  [ 0.          0.         -0.45289866  0.926643...
# traj1  [ 9.11783111e-043 -3.00000000e-001 -4.52898655...
# traj2  [ 8.71105862e-019 -5.25000000e-001 -4.52898655...
# traj3  [ 3.27136337e-001 -2.65099927e-001 -3.87471388...
# traj4  [ 5.92297530e-001 -2.85453168e-001 -2.69011882...
#
#                                                   agent3
# traj0  [ 0.          0.          0.55092992 -0.066128...
# traj1  [ 2.82695323e-185 -4.00000000e-001  5.50929917...
# traj2  [ 2.12021492e-185 -7.00000000e-001  5.50929917...
# traj3  [-1.66448890e-176 -9.25000000e-001  5.50929917...
# traj4  [-2.17503114e-140 -1.09375000e+000  5.50929917...

# %%
import pickle as pkl
path = r"D:\atlas\u\lantaoyu\exps\airl\simple_tag\decentralized\s-1000\l-0.1-b-1000-d-0.1-c-500-l2-0.1-iter-1-r-0.0\seed-1\m_04000-100tra.pkl"
with open(path, "rb") as f:
    datas = pkl.load(f)

data = datas[0]
ob = data['ob']
ob = np.array([[np.mean(x) for x in y] for y in ob])
data = ob
for i in range(len(data)):
    plt.scatter(np.arange(len(data[i])), data[i], color=cm.tab20(i))
plt.xlabel('Trajectory index')
plt.ylabel('Mean state')
plt.show()

data = datas[0]
ob = data['ob']
ob = np.array([[np.mean(x) for x in y] for y in ob])
ob = ob.T
df = pd.DataFrame(data = ob, index=["traj"+str(i) for i in range(ob.shape[0])], columns=['agent'+str(i) for i in range(ob.shape[1])])
# Out:
# [ 0.          0.         -0.54780504 -0.99846863 -0.03921793  1.58436789
#   0.70971515  1.47757651  1.32500256  0.36252054  0.09490638  1.92511234
#   1.09873496  0.93233991  0.          0.        ]
# [ 0.          0.          0.77719752 -0.63594808 -1.36422049  1.22184735
#  -0.61528741  1.11505597 -1.32500256 -0.36252054 -1.23009617  1.5625918
#  -0.2262676   0.56981937  0.          0.        ]

# %%
import pickle as pkl
path = r"D:\atlas\u\lantaoyu\exps\airl\simple_tag\decentralized\s-1000\l-0.1-b-1000-d-0.1-c-500-l2-0.1-iter-1-r-0.0\seed-1\m_04000-100tra.pkl"
with open(path, "rb") as f:
    datas = pkl.load(f)

print(datas[0].keys())

n_traj = 2
for t in range(n_traj):
    pos = np.array(datas[t]['pos'])
    posx = np.array([[pos[i][j][0] for j in range(len(pos[i]))] for i in range(len(pos))])
    posy = np.array([[pos[i][j][1] for j in range(len(pos[i]))] for i in range(len(pos))])
    for i in range(len(posx)):
        c = cm.tab20(i)
        c = (c[0], c[1], c[2], t/len(datas))
        plt.scatter(posx[i], posy[i], color=c)
plt.scatter(.5, .5, color=c)
plt.title('N_trajectory=100, N_step=50')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# dict_keys(['ob', 'ac', 'rew', 'ep_ret', 'all_ob', 'pos'])
