# %%
# %matplotlib inline
import pandas as pd
import numpy as np 
from tslearn.metrics import dtw 
import matplotlib.pyplot as plt 
import matplotlib.cm as cm

# %%
import json
import pickle
import numpy as np

def pickle_dump(obj, path):
    with open(path, mode='wb') as f:
        pickle.dump(obj,f)

def pickle_load(path):
    with open(path, mode='rb') as f:
        data = pickle.load(f)
        return data 

def mean_pre_nex(data, pre=5, nex=5):
    m_data = np.array(data)
    ave_data = []
    for i in np.arange(len(m_data)):
        p_pre = i-pre if i-pre>=0 else 0
        p_nex = i+nex if i+nex<len(m_data) else len(m_data)-1
        ave_data += [np.mean(m_data[p_pre:p_nex])]
    return ave_data  

def load_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

def load_json_lines(file_path):
    data = []
    with open(file_path, 'r') as f:
        for line in f:
            json_object = json.loads(line)
            data.append(json_object)
    return data

# %%
data = load_json_lines('./simple_tag_aairl.json')
print(data[0].keys())

keys = ['spearman 0', 'spearman 1']
target_x = [[] for _ in range(len(keys))]
target_y = [[] for _ in range(len(keys))]
for i, key in enumerate(keys):
    for d in data:
        if key in d:
            target_x[i].append(d['total_timesteps'])
            target_y[i].append(d[key])


for i in range(len(target_x)):
    plt.title('simple_speaker_listener (spearman)')
    plt.ylim(-1, 1)
    y = mean_pre_nex(target_y[i], pre=100, nex=100)
    plt.plot(target_x[i], y, label=keys[i])
plt.legend()
plt.show()
# Out:
# dict_keys(['nupdates', 'total_timesteps', 'fps', 'explained_variance 0', 'explained_variance 1', 'explained_variance 2', 'explained_variance 3', 'total_loss 0', 'total_loss 1', 'total_loss 2', 'total_loss 3'])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_47448/1680251272.py in <module>
#      13
#      14 for i in range(len(target_x)):
# ---> 15     plt.title('simple_speaker_listener (spearman)')
#      16     plt.ylim(-1, 1)
#      17     y = mean_pre_nex(target_y[i], pre=100, nex=100)
#
# NameError: name 'plt' is not defined

# %%
data = load_json_lines('./simple_mfg_tag.json')
print(data[10].keys())
# Out:
# dict_keys(['nupdates', 'total_timesteps', 'fps', 'explained_variance 0', 'policy_entropy 0', 'policy_loss 0', 'value_loss 0', 'pearson 0', 'spearman 0', 'reward 0', 'explained_variance 1', 'policy_entropy 1', 'policy_loss 1', 'value_loss 1', 'pearson 1', 'spearman 1', 'reward 1', 'explained_variance 2', 'policy_entropy 2', 'policy_loss 2', 'value_loss 2', 'pearson 2', 'spearman 2', 'reward 2', 'explained_variance 3', 'policy_entropy 3', 'policy_loss 3', 'value_loss 3', 'pearson 3', 'spearman 3', 'reward 3', 'explained_variance 4', 'policy_entropy 4', 'policy_loss 4', 'value_loss 4', 'pearson 4', 'spearman 4', 'reward 4', 'explained_variance 5', 'policy_entropy 5', 'policy_loss 5', 'value_loss 5', 'pearson 5', 'spearman 5', 'reward 5', 'explained_variance 6', 'policy_entropy 6', 'policy_loss 6', 'value_loss 6', 'pearson 6', 'spearman 6', 'reward 6', 'explained_variance 7', 'policy_entropy 7', 'policy_loss 7', 'value_loss 7', 'pearson 7', 'spearman 7', 'reward 7', 'explained_variance 8', 'policy_entropy 8', 'policy_loss 8', 'value_loss 8', 'pearson 8', 'spearman 8', 'reward 8', 'explained_variance 9', 'policy_entropy 9', 'policy_loss 9', 'value_loss 9', 'pearson 9', 'spearman 9', 'reward 9', 'explained_variance 10', 'policy_entropy 10', 'policy_loss 10', 'value_loss 10', 'pearson 10', 'spearman 10', 'reward 10', 'explained_variance 11', 'policy_entropy 11', 'policy_loss 11', 'value_loss 11', 'pearson 11', 'spearman 11', 'reward 11', 'explained_variance 12', 'policy_entropy 12', 'policy_loss 12', 'value_loss 12', 'pearson 12', 'spearman 12', 'reward 12', 'explained_variance 13', 'policy_entropy 13', 'policy_loss 13', 'value_loss 13', 'pearson 13', 'spearman 13', 'reward 13', 'explained_variance 14', 'policy_entropy 14', 'policy_loss 14', 'value_loss 14', 'pearson 14', 'spearman 14', 'reward 14', 'explained_variance 15', 'policy_entropy 15', 'policy_loss 15', 'value_loss 15', 'pearson 15', 'spearman 15', 'reward 15', 'explained_variance 16', 'policy_entropy 16', 'policy_loss 16', 'value_loss 16', 'pearson 16', 'spearman 16', 'reward 16', 'explained_variance 17', 'policy_entropy 17', 'policy_loss 17', 'value_loss 17', 'pearson 17', 'spearman 17', 'reward 17', 'explained_variance 18', 'policy_entropy 18', 'policy_loss 18', 'value_loss 18', 'pearson 18', 'spearman 18', 'reward 18', 'explained_variance 19', 'policy_entropy 19', 'policy_loss 19', 'value_loss 19', 'pearson 19', 'spearman 19', 'reward 19', 'total_loss 0', 'total_loss 1', 'total_loss 2', 'total_loss 3', 'total_loss 4', 'total_loss 5', 'total_loss 6', 'total_loss 7', 'total_loss 8', 'total_loss 9', 'total_loss 10', 'total_loss 11', 'total_loss 12', 'total_loss 13', 'total_loss 14', 'total_loss 15', 'total_loss 16', 'total_loss 17', 'total_loss 18', 'total_loss 19'])

# %%
keys = ['spearman '+str(i) for i in [0, 5, 10, 15]]
target_x = [[] for _ in range(len(keys))]
target_y = [[] for _ in range(len(keys))]
for i, key in enumerate(keys):
    for d in data:
        if key in d:
            target_x[i].append(d['total_timesteps'])
            target_y[i].append(d[key])


for i in range(len(target_x)):
    plt.title('simple_mfg_tag (spearman)')
    plt.ylim(-1, 1)
    y = mean_pre_nex(target_y[i], pre=10, nex=10)
    plt.plot(target_x[i], y, label='Group'+str(i))
plt.legend()
plt.show()

# %%
keys = ['explained_variance '+str(i) for i in [0, 5, 10, 15]]
target_x = [[] for _ in range(len(keys))]
target_y = [[] for _ in range(len(keys))]
for i, key in enumerate(keys):
    for d in data:
        if key in d:
            target_x[i].append(d['total_timesteps'])
            target_y[i].append(d[key])


for i in range(len(target_x)):
    plt.title('simple_mfg_tag (test)')
    #plt.ylim(-1, 1)
    y = mean_pre_nex(target_y[i], pre=10, nex=10)
    plt.plot(target_x[i], y, label='Group'+str(i))
plt.legend()
plt.show()
